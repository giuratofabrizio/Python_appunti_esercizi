# %% [markdown]
# # Esercitazione MatPlotLib
#  Esercizi Riusciti:
# *   Creazione Dataframes
# *   Valori in percentuale (creazione di perc nell'ultima cella)
#
#  Esercizi NON Riusciti:
# *   Creazione grafici esposti su Classroom

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/somministrazioni-vaccini-latest.csv')
df
# Out:
#        data_somministrazione  ...              nome_area
# 0                 2020-12-27  ...                Abruzzo
# 1                 2020-12-27  ...                Abruzzo
# 2                 2020-12-27  ...                Abruzzo
# 3                 2020-12-27  ...                Abruzzo
# 4                 2020-12-27  ...                Abruzzo
# ...                      ...  ...                    ...
# 159153            2021-12-07  ...                 Veneto
# 159154            2021-12-07  ...                 Veneto
# 159155            2021-12-07  ...                 Veneto
# 159156            2021-12-07  ...  Friuli-Venezia Giulia
# 159157            2021-12-07  ...                Sicilia
#
# [159158 rows x 14 columns]

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/platea.csv')
df1
# Out:
#     area nome_area fascia_anagrafica  totale_popolazione
# 0    ABR   Abruzzo             12-19               94727
# 1    ABR   Abruzzo             20-29              125230
# 2    ABR   Abruzzo             30-39              146965
# 3    ABR   Abruzzo             40-49              187162
# 4    ABR   Abruzzo             50-59              208686
# ..   ...       ...               ...                 ...
# 163  VEN    Veneto             40-49              715790
# 164  VEN    Veneto             50-59              806474
# 165  VEN    Veneto             60-69              610635
# 166  VEN    Veneto             70-79              494721
# 167  VEN    Veneto               80+              370529
#
# [168 rows x 4 columns]

# %%
df1.groupby('area')['totale_popolazione'].value_counts().unstack(0).plot.bar()

#Creazione di doppie assi per ogni indice come fatto nell'esercizio del 24/11

# %%
perc = df1.groupby('area')['totale_popolazione'].value_counts(normalize=True)

# perc = valore percentuale della popolazione totale per ogni area(groupby)


fig = plt.figure()
ax = plt.axes()

ax.bar(df1.index, perc.values, color='r')

#Creazione del grafico con indici di DF1 e valori in percentuale presi da perc
# Out:
# Text(0.5, 0.98, 'Numero di film per ogni lingua')
