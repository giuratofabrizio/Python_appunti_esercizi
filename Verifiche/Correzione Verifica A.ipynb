# %% [markdown]
# scrivere un programma che calcoli la somma di due frazioni. L’utente deve inserire il numeratore e il denominatore della prima frazione e poi numeratore e denominatore della seconda frazione e il programma calcola la somma.

# %%
n1= int(input("inserire n1"))
d1= int(input("inserire d1"))
n2= int(input("inserire n2"))
d2= int(input("inserire d2"))
print(str(n1*d2+n2*d1)+'/'+(str(d1*d2)))

# %% [markdown]
# scrivere un programma che permetta di verificare se un orario è scritto correttamente. Un orario è scritto correttamente se è formato da 5 caratteri di cui il terzo è il carattere : . Ad esempio 13:45 è scritto correttamente 123:4 non è scritto correttamente.

# %%
orario= input('inserisci orario: ')
if len(orario) == 5:               #orario = valore attuale
  if orario[2] == ':':
    print(orario)
    print('orario corretto')
  else:
    print('orario inserito erroneamente')
else:
  print('orario inserito erronamente')

# %% [markdown]
# scrivere un programma che visualizzi le prime dieci potenze di un numero inserito dall’utente. Ad esempio se l’utente inserisse 2 il programma dovrebbe visualizzare i valori 1, 2, 4, 8, 16, 32, 64, 128, 256 e 512. Separare i valori con il trattino -

# %%
numero = int(input('inserire la base delle potenze: '))
for i in range(0,10):
  print(numero**i)
# Out:
# inserire la base delle potenze: 2
# 1
# 2
# 4
# 8
# 16
# 32
# 64
# 128
# 256
# 512

# %% [markdown]
# scrivere un programma che carichi in una lista le prime venti potenze di un numero inserito dall’utente. Al termine visualizzare gli ultimi tre elementi della lista.

# %%
potenze= []
numero = int(input('inserire la base delle potenze: '))
for i in range(0,20):
  potenze.append(numero**i)
print(potenze[-3:])
# Out:
# inserire la base delle potenze: 2
# [131072, 262144, 524288]

# %%
numero = int(input('inserire la base delle potenze: '))
potenza = [numero**i for i in range(0,10)]
print(potenza[-3:])
# Out:
# inserire la base delle potenze: 2
# [128, 256, 512]

# %% [markdown]
# scrivere un programma che elimini dalla lista precedente tutti i numeri compresi tra due estremi inseriti dall’utente. Visualizzare al termine la lista modificata

# %%
e1= int(input('inserire primo estremo: '))
e2= int(input('inserire secondo estremo: '))
print(potenza)

for i in range(0,10):
  if e1 < potenza[i] < e2:
    potenza.remove(potenza[i])

print(potenza)

# %% [markdown]
# scrivere una funzione chiamata prodotto che data una lista di numeri interi restituisca il prodotto di tutti i suoi elementi. Ad esempio se la lista fosse [2, 5, 3] la funzione restituirebbe 30

# %%
def prodotto(l):
  totale = 1
  for e in l:
    totale = totale * e
  return totale  

lista = [int(elemento) for elemento in input('inserire numeri ').split()]
prodotto(lista)
# Out:
# inserire numeri 4 6 8 3 5 7
# 20160

# %% [markdown]
# scrivere un programma che permetta di caricare in una struttura dati opportuna i nomi delle nazioni che compongono l’Unione Europea, le loro capitali e la popolazione (inserire solo tre nazioni). Visualizzare poi i dati di una nazione inserita dall’utente

# %%
unioneEuropea = [{'nome':'Italia', 'capitale':'Roma', 'popolazione': 60},
                 {'nome':'Francia', 'capitale':'Parigi', 'popolazione': 58},
                 {'nome':'Germania', 'capitale':'Berlino', 'popolazione': 80}]
nazione= input('inserisci nazione: ')

# %% [markdown]
# scrivere un programma che, utilizzando una lambda function e la funzione map, elevi alla terza tutti gli elementi della lista. La lista deve essere caricata dall’utente.

# %%
lista = [int(elemento) for elemento in input('inserire numeri ').split()]
listafinale = list(map(lambda x: x**3, lista))
print(listafinale)
# Out:
# inserire numeri 1 7 12 4
# [1, 343, 1728, 64]

# %% [markdown]
# scrivere una funzione che calcoli in modo ricorsivo il prodotto tra due numeri.

# %%
def prodotto2(f1,f2):
  if f2 == 1:
    return f1
  else:
    return f1 + prodotto2(f1, f2-1)

prodotto2(5,4)
# Out:
# 20
