# %% [markdown]
# 1. Scrivere un programma che crei un dizionario contenente i nomi delle regioni e dei loro capoluoghi. il nome della regione deve essere il campo chiave. chiamare il dizionario capoluoghiRegione

# %%
capoluoghiRegione = {'Abruzzo':'LAquila' , 'Basilicata':'Potenza' , 'Calabria':'Catanzaro' , 'Campania':'Napoli' , 'EmiliaRomagna':'Bologna' , 'Friuli':'Trieste' , 'Lazio':'Roma' , 'Liguria':'Genova' , 'Lombardia':'Milano' , 'Marche':'Ancona' , 'Molise':'Campobasso' , 'Piemonte':'Torino' , 'Puglia':'Bari' , 'Sardegna':'Cagliari' , 'Sicilia':'Palermo' , 'Toscana':'Firenze' , 'Trentino':'Trento' , 'Umbria':'Perugia' , 'ValleDAosta':'Aosta' , 'Veneto':'Venezia'}

# %% [markdown]
# 2. Scrivere un programma che visualizzi tutti i nomi delle regioni contenute in capoluoghiRegione

# %%
print(capoluoghiRegione.keys())
# Out:
# dict_keys(['Abruzzo', 'Basilicata', 'Calabria', 'Campania', 'EmiliaRomagna', 'Friuli', 'Lazio', 'Liguria', 'Lombardia', 'Marche', 'Molise', 'Piemonte', 'Puglia', 'Sardegna', 'Sicilia', 'Toscana', 'Trentino', 'Umbria', 'ValleDAosta', 'Veneto'])

# %% [markdown]
# 3. Scrivere un programma che visualizzi tutti i nomi dei capoluoghi contenuti in capoluoghiRegione

# %%
print(capoluoghiRegione.values())
# Out:
# dict_values(['LAquila', 'Potenza', 'Catanzaro', 'Napoli', 'Bologna', 'Trieste', 'Roma', 'Genova', 'Milano', 'Ancona', 'Campobasso', 'Torino', 'Bari', 'Cagliari', 'Palermo', 'Firenze', 'Trento', 'Perugia', 'Aosta', 'Venezia'])

# %% [markdown]
# 4. Scrivere un programma che acquisisca dall’utente il nome di una regione e fornisca il nome del suo
# capoluogo.

# %%
a = input(' ')
print(capoluoghiRegione[a])
# Out:
#  Molise
# Campobasso

# %% [markdown]
# 5. Scrivere un programma che acquisisca dall’utente il nome di un capoluogo e fornisca il nome della
# regione a cui appartiene.

# %%
items = list(capoluoghiRegione.items())
cap = input()

for item in items:
  if item[1]==cap:
    c = item[0]

print(c)
# Out:
# Catanzaro
# Calabria

# %% [markdown]
# 6. Scrivere un programma che visualizzi tutte le regioni con i rispettivi capoluoghi

# %%
keys = list(capoluoghiRegione.keys())
values = list(capoluoghiRegione.values())

for i in range(len(capoluoghiRegione)):
  print(keys[i], values[i])
# Out:
# Abruzzo LAquila
# Basilicata Potenza
# Calabria Catanzaro
# Campania Napoli
# EmiliaRomagna Bologna
# Friuli Trieste
# Lazio Roma
# Liguria Genova
# Lombardia Milano
# Marche Ancona
# Molise Campobasso
# Piemonte Torino
# Puglia Bari
# Sardegna Cagliari
# Sicilia Palermo
# Toscana Firenze
# Trentino Trento
# Umbria Perugia
# ValleDAosta Aosta
# Veneto Venezia

# %% [markdown]
# 7. Scrivere un programma che visualizzi tutte le regioni con i rispettivi capoluoghi. Ordinare le regioni
# in ordine alfabetico

# %%
keys = list(capoluoghiRegione.keys())
values = list(capoluoghiRegione.values())

for i in range(len(capoluoghiRegione)):
  keys.sort()
  print(keys[i], values[i])
# Out:
# Abruzzo LAquila
# Basilicata Potenza
# Calabria Catanzaro
# Campania Napoli
# EmiliaRomagna Bologna
# Friuli Trieste
# Lazio Roma
# Liguria Genova
# Lombardia Milano
# Marche Ancona
# Molise Campobasso
# Piemonte Torino
# Puglia Bari
# Sardegna Cagliari
# Sicilia Palermo
# Toscana Firenze
# Trentino Trento
# Umbria Perugia
# ValleDAosta Aosta
# Veneto Venezia

# %% [markdown]
# 8. Scrivere un programma che visualizzi tutte le regioni con i rispettivi capoluoghi. Ordinare i
# capoluoghi in ordine alfabetico

# %%
keys = list(capoluoghiRegione.keys())
values = sorted(list(capoluoghiRegione.values()))
o = ['']*20

for reg in keys:
  indice = values.index(capoluoghiRegione[reg])
  o[indice] = reg 

for cap in values:
  print(o[values.index(cap)], cap)
# Out:
# Marche Ancona
# ValleDAosta Aosta
# Puglia Bari
# EmiliaRomagna Bologna
# Sardegna Cagliari
# Molise Campobasso
# Calabria Catanzaro
# Toscana Firenze
# Liguria Genova
# Abruzzo LAquila
# Lombardia Milano
# Campania Napoli
# Sicilia Palermo
# Umbria Perugia
# Basilicata Potenza
# Lazio Roma
# Piemonte Torino
# Trentino Trento
# Friuli Trieste
# Veneto Venezia

# %% [markdown]
# 9. Scrivere un programma che carichi in una lista i nomi delle regioni e in un’altra lista i nomi dei
# rispettivi capoluoghi. Scrivere poi l’istruzione che permette di costruire il dizionario a partire dalle
# due liste.

# %%
regioni = list(capoluoghiRegione.keys())
citta = list(capoluoghiRegione.values())

[(cittaeregioni) for cittaeregioni in zip(regioni,citta)]
cer= dict((cittaeregioni) for cittaeregioni in zip(regioni,citta))
print(cer)
# Out:
# {'Abruzzo': 'LAquila', 'Basilicata': 'Potenza', 'Calabria': 'Catanzaro', 'Campania': 'Napoli', 'EmiliaRomagna': 'Bologna', 'Friuli': 'Trieste', 'Lazio': 'Roma', 'Liguria': 'Genova', 'Lombardia': 'Milano', 'Marche': 'Ancona', 'Molise': 'Campobasso', 'Piemonte': 'Torino', 'Puglia': 'Bari', 'Sardegna': 'Cagliari', 'Sicilia': 'Palermo', 'Toscana': 'Firenze', 'Trentino': 'Trento', 'Umbria': 'Perugia', 'ValleDAosta': 'Aosta', 'Veneto': 'Venezia'}
